# %% [markdown]
# # Pokedex Exploratory Data Analysis

# %% [markdown]
# ## 1. Importing Libraries and Data Set

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.chdir(r'C:\Javeria\Projects\Data Science Roadmap\EDA - Week 8\Pokemon dataset EDA')

# %%
df=pd.read_csv('pokemons.csv')
df.head()
# Out:
#    id        name      rank    generation evolves_from  type1   type2  hp  \
# 0   1   bulbasaur  ordinary  generation-i      nothing  grass  poison  45
# 1   2     ivysaur  ordinary  generation-i    bulbasaur  grass  poison  60
# 2   3    venusaur  ordinary  generation-i      ivysaur  grass  poison  80
# 3   4  charmander  ordinary  generation-i      nothing   fire     NaN  39
# 4   5  charmeleon  ordinary  generation-i   charmander   fire     NaN  58
#
#    atk  def  spatk  spdef  speed  total  height  weight  \
# 0   49   49     65     65     45    318       7      69
# 1   62   63     80     80     60    405      10     130
# 2   82   83    100    100     80    525      20    1000
# 3   52   43     60     50     65    309       6      85
# 4   64   58     80     65     80    405      11     190
#
#                abilities                                               desc
# 0  overgrow chlorophyll   A strange seed was planted on its back at birt...
# 1  overgrow chlorophyll   When the bulb on its back grows large, it appe...
# 2  overgrow chlorophyll   The plant blooms when it is absorbing solar en...
# 3     blaze solar-power   Obviously prefers hot places. When it rains, s...
# 4     blaze solar-power   When it swings its burning tail, it elevates t...

# %% [markdown]
# ## 2. Exploring the Dataset

# %%
df.shape
# Out:
# (1025, 18)

# %%
df.columns
# Out:
# Index(['id', 'name', 'rank', 'generation', 'evolves_from', 'type1', 'type2',
#        'hp', 'atk', 'def', 'spatk', 'spdef', 'speed', 'total', 'height',
#        'weight', 'abilities', 'desc'],
#       dtype='object')

# %% [markdown]
# #### What do the columns stand for?

# %% [markdown]
# id = pokedex id of the pokemon
#
# name = name of the pokemon
#
# rank = whether the pokemon is legendary, ordinary, mythical or baby
#
# generation = generation of each pokemon
#
# evolves_from = the pokemon's prior form
#
# type1 = primary type of the pokemon
#
# type2 = secondary type of the pokemon
#
# hp = hp stat
#
# atk = attack stat
#
# def = defense stat
#
# spatk = special attack stat
#
# spdef = special defense stat
#
# speed = speed stat
#
# total = sum of all the stats
#
# height = height in decimeters
#
# weight = weight in hectograms
#
# abilities = abilities of the pokemon
#
# desc = short description about the pokemon

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1025 non-null   int64
#  1   name          1025 non-null   object
#  2   rank          1025 non-null   object
#  3   generation    1025 non-null   object
#  4   evolves_from  1025 non-null   object
#  5   type1         1025 non-null   object
#  6   type2         526 non-null    object
#  7   hp            1025 non-null   int64
#  8   atk           1025 non-null   int64
#  9   def           1025 non-null   int64
#  10  spatk         1025 non-null   int64
#  11  spdef         1025 non-null   int64
#  12  speed         1025 non-null   int64
#  13  total         1025 non-null   int64
#  14  height        1025 non-null   int64
#  15  weight        1025 non-null   int64
#  16  abilities     1025 non-null   object
#  17  desc          1025 non-null   object
# dtypes: int64(10), object(8)
# memory usage: 144.3+ KB

# %% [markdown]
# Here we realize that the only null values are in the type2 column.

# %%
df.describe()
# Out:
#                 id           hp          atk          def        spatk  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean    513.000000    70.184390    77.521951    72.507317    70.080976
# std     296.036315    26.631054    29.782541    29.286972    29.658378
# min       1.000000     1.000000     5.000000     5.000000    10.000000
# 25%     257.000000    50.000000    55.000000    50.000000    47.000000
# 50%     513.000000    68.000000    75.000000    70.000000    65.000000
# 75%     769.000000    85.000000   100.000000    90.000000    90.000000
# max    1025.000000   255.000000   181.000000   230.000000   173.000000
#
#              spdef        speed        total       height       weight
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean     70.205854    67.186341   427.686829    12.116098   669.865366
# std      26.639329    28.717227   112.770735    12.481673  1212.731138
# min      20.000000     5.000000   175.000000     1.000000     1.000000
# 25%      50.000000    45.000000   325.000000     5.000000    85.000000
# 50%      67.000000    65.000000   450.000000    10.000000   280.000000
# 75%      86.000000    88.000000   508.000000    15.000000   700.000000
# max     230.000000   200.000000   720.000000   200.000000  9999.000000

# %%
sns.histplot(data=df, x="total")
plt.title('Total Stats Histogram')
plt.show()

# %%
sns.boxplot(y='total', data=df)
plt.title('Total Stats Boxplot')
plt.show()

# %% [markdown]
# # 3. Analysis

# %% [markdown]
# ## 3.1 Starter Pokemons

# %%
df_start_poke=df.iloc[:9:3,:]

# %%
df_start_poke
# Out:
#    id        name      rank    generation evolves_from  type1   type2  hp  \
# 0   1   bulbasaur  ordinary  generation-i      nothing  grass  poison  45
# 3   4  charmander  ordinary  generation-i      nothing   fire     NaN  39
# 6   7    squirtle  ordinary  generation-i      nothing  water     NaN  44
#
#    atk  def  spatk  spdef  speed  total  height  weight  \
# 0   49   49     65     65     45    318       7      69
# 3   52   43     60     50     65    309       6      85
# 6   48   65     50     64     43    314       5      90
#
#                abilities                                               desc
# 0  overgrow chlorophyll   A strange seed was planted on its back at birt...
# 3     blaze solar-power   Obviously prefers hot places. When it rains, s...
# 6     torrent rain-dish   After birth, its back swells and hardens into ...

# %%
plt.figure(figsize=(12,6))

x=np.arange(len(df_start_poke.name))
w=0.2
plt.bar(x,df_start_poke.atk, w,color='red',label='Attack')
plt.bar(x+w,df_start_poke['def'],w, color='green',label='Defense')
plt.bar(x+(2*w),df_start_poke['hp'],w, color='blue',label='HP')

plt.title('Stats for Starter Pokemon', fontsize=15)
plt.xlabel('Pokemon name')
plt.xticks(x+w, df_start_poke.name)
plt.legend()
plt.show()

# %% [markdown]
# #### Pokémon Selection Insight
#
# For anyone who prioritizes Pokémon's attacking ability, **their clear choice among the three will be Charmander**.
#
# However, within Squirtle and Bulbasaur:
# - **Squirtle** should be a wiser choice given its significantly better defense system.
# - The attacking ability and HP of Squirtle and Bulbasaur are almost the same.

# %% [markdown]
# ## 3.2 Types of Pokemons

# %%
df.type1.unique()
# Out:
# array(['grass', 'fire', 'water', 'bug', 'normal', 'poison', 'electric',
#        'ground', 'fairy', 'fighting', 'psychic', 'rock', 'ghost', 'ice',
#        'dragon', 'dark', 'steel', 'flying'], dtype=object)

# %%
df.type2.unique()
# Out:
# array(['poison', nan, 'flying', 'ground', 'fairy', 'grass', 'fighting',
#        'psychic', 'steel', 'ice', 'rock', 'water', 'electric', 'fire',
#        'dragon', 'dark', 'ghost', 'bug', 'normal'], dtype=object)

# %% [markdown]
# ### 3.2.1 Analysis on Primary type of Pokemon

# %%
df.type1.value_counts()
# Out:
# type1
# water       134
# normal      118
# grass       103
# bug          83
# fire         66
# psychic      60
# electric     59
# rock         58
# dark         45
# poison       42
# fighting     40
# ground       40
# dragon       37
# steel        36
# ghost        35
# ice          31
# fairy        29
# flying        9
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='type1', data=df, order=df.type1.value_counts().index)
plt.title('Primary types of Pokemons', fontsize=15)
plt.xlabel('Pokemon type');

# %%
#Making a df for pokemon types and their average attack, defense and total scores
columns_to_show = ['atk','def','total']
df_type_stats = df.groupby(df.type1)[columns_to_show].mean()
df_type_stats.reset_index(inplace=True)
df_type_stats
# Out:
#        type1         atk         def       total
# 0        bug   67.554217   69.578313  374.638554
# 1       dark   88.000000   71.622222  454.733333
# 2     dragon   98.972973   75.216216  490.162162
# 3   electric   72.966102   62.101695  436.305085
# 4      fairy   66.827586   70.965517  436.068966
# 5   fighting  102.700000   72.350000  441.550000
# 6       fire   82.606061   66.833333  446.196970
# 7     flying   79.888889   66.000000  436.111111
# 8      ghost   68.600000   75.485714  431.171429
# 9      grass   74.349515   70.893204  413.116505
# 10    ground   93.400000   85.900000  434.575000
# 11       ice   74.419355   73.806452  436.387097
# 12    normal   74.381356   59.855932  399.838983
# 13    poison   75.547619   72.833333  426.333333
# 14   psychic   63.000000   67.016667  446.716667
# 15      rock   86.465517   98.103448  441.155172
# 16     steel   88.000000  111.083333  475.083333
# 17     water   72.343284   70.283582  418.865672

# %%
plt.figure(figsize=(12,6))

plt.plot(df_type_stats.type1,df_type_stats.atk, color='red',label='Attack')
plt.plot(df_type_stats.type1,df_type_stats['def'], color='green',label='Defense')

plt.title('Stats for Pokemon Types')
plt.ylabel('mean stat values')
plt.xlabel('Primary pokemon type')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.bar(df_type_stats.type1,df_type_stats['total'], color='black',label='Total Stats')
plt.title('Total Stats for Pokemon types')
plt.ylim(350,500)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Pokemon Type Insight
# **Steel and Dragon Pokémon** have the highest total stats on average among the types of Pokémon.
#
# - **Dragon Pokémon**:
#   - Strength: Attacking ability
#
# - **Steel Pokémon**:
#   - Strength: Defense ability

# %% [markdown]
# #### 3.2.1.1 Top Steel Pokemons

# %%
df_steel=df[df.type1=='steel']
df_steel10=df_steel.sort_values(by='total', ascending=False).head(10)
df_steel10.head(3)
# Out:
#         id        name       rank      generation evolves_from  type1   type2  \
# 482    483      dialga  legendary   generation-iv      nothing  steel  dragon
# 1017  1018  archaludon   ordinary   generation-ix    duraludon  steel  dragon
# 808    809    melmetal   mythical  generation-vii       meltan  steel     NaN
#
#        hp  atk  def  spatk  spdef  speed  total  height  weight  \
# 482   100  120  120    150    100     90    680      54    6830
# 1017   90  105  130    125     65     85    600      20     600
# 808   135  143  143     80     65     34    600      25    8000
#
#                      abilities  \
# 482        pressure telepathy
# 1017  stamina sturdy stalwart
# 808                 iron-fist
#
#                                                    desc
# 482   It has the power to control time. It appears i...
# 1017                                      Not Available
# 808   Revered long ago for its capacity to create ir...

# %%
plt.figure(figsize=(12,6))
plt.bar(df_steel10.name,df_steel10['total'], color='black')

plt.xticks(rotation=45)
plt.title('Top 10 Steel Pokemons', fontsize=18)
plt.xlabel('Pokemon name')
plt.ylabel('Total stat score')
plt.ylim(450,)
plt.show()

# %% [markdown]
# #### 3.2.1.2 Top Dragon Pokemons

# %%
df_drag=df[df.type1=='dragon']
df_drag10=df_drag.sort_values(by=['total','atk'], ascending=False).head(10)
df_drag10.head(3)
# Out:
#       id      name       rank      generation evolves_from   type1     type2  \
# 383  384  rayquaza  legendary  generation-iii      nothing  dragon    flying
# 643  644    zekrom  legendary    generation-v      nothing  dragon  electric
# 642  643  reshiram  legendary    generation-v      nothing  dragon      fire
#
#       hp  atk  def  spatk  spdef  speed  total  height  weight    abilities  \
# 383  105  150   90    150     90     95    680      70    2065    air-lock
# 643  100  150  120    120    100     90    680      29    3450    teravolt
# 642  100  120  100    150    120     90    680      32    3300  turboblaze
#
#                                                   desc
# 383  RAYQUAZA lived for hundreds of millions of yea...
# 643  Concealing itself in lightning clouds, it flie...
# 642  This Pokémon appears in legends. It sends flam...

# %%
plt.figure(figsize=(12,6))
plt.bar(df_drag10.name,df_drag10['total'], color='black')

plt.xticks(rotation=45)
plt.title('Top 10 Dragon Pokemons', fontsize=18)
plt.xlabel('Pokemon name')
plt.ylabel('Total stat score')
plt.ylim(450,)
plt.show()

# %% [markdown]
# ### 3.2.2 Analysis on secondary or combined type of Pokemon

# %%
df.type2.value_counts()
# Out:
# type2
# flying      100
# psychic      42
# poison       41
# ground       35
# fairy        35
# dragon       33
# fighting     33
# ghost        30
# steel        29
# grass        24
# dark         24
# water        20
# ice          17
# rock         16
# fire         15
# normal       13
# electric     10
# bug           9
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='type2',data=df, order=df.type2.value_counts().index)
plt.title('Secondary types of Pokemons');

# %%
total_type_counts=pd.DataFrame(df.type2.value_counts()+df.type1.value_counts())
tt_counts=total_type_counts.sort_values('count',ascending=False)
tt_counts.reset_index(inplace=True)
tt_counts.columns = ['type', 'count']
tt_counts
# Out:
#         type  count
# 0      water    154
# 1     normal    131
# 2      grass    127
# 3     flying    109
# 4    psychic    102
# 5        bug     92
# 6     poison     83
# 7       fire     81
# 8     ground     75
# 9       rock     74
# 10  fighting     73
# 11    dragon     70
# 12  electric     69
# 13      dark     69
# 14     ghost     65
# 15     steel     65
# 16     fairy     64
# 17       ice     48

# %%
plt.figure(figsize=(9,4))
plt.bar(tt_counts['type'],tt_counts['count'])
plt.title('Total types of Pokemons')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Most common and rare pokemon Insight
#
# Given the types of Pokémon, regardless of their primary or secondary type, **the most common Pokémon types are Water, Normal, and Grass**.
#
# However, **the rarest types of Pokémon are Ice, Fairy, and Steel**.
#
# Hence, if one wants an Ice Pokémon in their Pokémon portfolio and comes across it, **they shouldn't let it go**.

# %%
#Finding out the most common types of the pokemon that have both primary and secondary type
crosstab=pd.crosstab(df.type1,df.type2)
crosstab
# Out:
# type2     bug  dark  dragon  electric  fairy  fighting  fire  flying  ghost  \
# type1
# bug         0     1       0         4      2         4     2      13      1
# dark        0     0       4         0      3         2     3       6      1
# dragon      0     1       0         1      0         2     1       4      3
# electric    0     1       3         0      2         2     0       5      1
# fairy       0     0       0         0      0         1     0       3      0
# fighting    0     2       1         1      0         0     0       1      2
# fire        2     1       2         0      0         6     0       6      3
# flying      0     1       2         0      0         1     0       0      0
# ghost       0     1       1         0      2         0     3       2      0
# grass       0     5       5         0      5         3     1       6      5
# ground      0     3       2         1      0         1     0       3      3
# ice         2     0       0         0      0         0     0       2      1
# normal      0     0       1         0      4         2     0      27      0
# poison      1     3       3         0      1         3     2       3      1
# psychic     0     0       0         0      7         1     1       6      2
# rock        2     1       2         1      2         1     2       4      0
# steel       0     0       3         0      3         1     0       2      4
# water       2     4       4         2      4         3     0       7      3
#
# type2     grass  ground  ice  normal  poison  psychic  rock  steel  water
# type1
# bug           6       1    0       0      11        3     4      5      3
# dark          2       1    3       1       1        2     0      3      0
# dragon        0       4    4       1       0        2     0      0      1
# electric      0       1    1       2       2        0     0      4      0
# fairy         0       0    0       0       0        1     0      3      0
# fighting      0       0    1       0       1        2     0      1      0
# fire          0       2    0       2       1        2     1      1      1
# flying        0       0    0       0       0        0     0      1      1
# ghost         5       2    0       0       3        0     0      0      0
# grass         0       1    2       3      14        3     0      3      0
# ground        2       0    0       1       0        2     3      2      0
# ice           0       3    0       0       0        3     0      0      4
# normal        2       1    0       0       0        5     0      0      1
# poison        0       3    0       2       0        1     0      0      3
# psychic       2       0    0       1       0        0     0      1      0
# rock          2       6    2       0       3        3     0      4      6
# steel         0       1    0       0       2        7     3      0      0
# water         3       9    4       0       3        6     5      1      0

# %%
sns.heatmap(crosstab, annot=True, cmap='coolwarm', fmt='d')
plt.xlabel('Type 2')
plt.ylabel('Type 1')
plt.title('Cross Tabulation Heatmap')
# Out:
# Text(0.5, 1.0, 'Cross Tabulation Heatmap')

# %% [markdown]
# Among the double type pokemons, the **highest amount of pokemons belong to the normal flying category** followed by the grass poison type

# %%
highest_value = crosstab.max().max()
highest_value
# Out:
# 27

# %%
highest_indices = crosstab.stack()[crosstab.stack() == highest_value].index.to_list()
highest_indices
# Out:
# [('normal', 'flying')]

# %%
df[(df.type1 == 'normal') & (df.type2 == 'flying')].head()
# Out:
#     id       name      rank    generation evolves_from   type1   type2  hp  \
# 15  16     pidgey  ordinary  generation-i      nothing  normal  flying  40
# 16  17  pidgeotto  ordinary  generation-i       pidgey  normal  flying  63
# 17  18    pidgeot  ordinary  generation-i    pidgeotto  normal  flying  83
# 20  21    spearow  ordinary  generation-i      nothing  normal  flying  40
# 21  22     fearow  ordinary  generation-i      spearow  normal  flying  65
#
#     atk  def  spatk  spdef  speed  total  height  weight  \
# 15   45   40     35     35     56    251       3      18
# 16   60   55     50     50     71    349      11     300
# 17   80   75     70     70    101    479      15     395
# 20   60   30     31     31     70    262       3      20
# 21   90   65     61     61    100    442      12     380
#
#                            abilities  \
# 15  keen-eye tangled-feet big-pecks
# 16  keen-eye tangled-feet big-pecks
# 17  keen-eye tangled-feet big-pecks
# 20                  keen-eye sniper
# 21                  keen-eye sniper
#
#                                                  desc
# 15  A common sight in forests and woods. It flaps ...
# 16  Very protective of its sprawling territorial a...
# 17  When hunting, it skims the surface of water at...
# 20  It flaps its small wings busily to fly. Using ...
# 21  With its huge and magnificent wings, it can ke...

# %% [markdown]
# ## 3.3 Top 10 pokemons

# %%
df_top10 = df.sort_values('total', ascending=False).head(10)
df_top10.head()
# Out:
#       id       name       rank       generation evolves_from   type1  \
# 492  493     arceus   mythical    generation-iv      nothing  normal
# 889  890  eternatus  legendary  generation-viii      nothing  poison
# 383  384   rayquaza  legendary   generation-iii      nothing  dragon
# 643  644     zekrom  legendary     generation-v      nothing  dragon
# 486  487   giratina  legendary    generation-iv      nothing   ghost
#
#         type2   hp  atk  def  spatk  spdef  speed  total  height  weight  \
# 492       NaN  120  120  120    120    120    120    720      32    3200
# 889    dragon  140   85   95    145     95    130    690     200    9500
# 383    flying  105  150   90    150     90     95    680      70    2065
# 643  electric  100  150  120    120    100     90    680      29    3450
# 486    dragon  150  100  120    100    120     90    680      45    7500
#
#                abilities                                               desc
# 492           multitype   It is described in mythology as the Pokémon th...
# 889            pressure   The core on its chest absorbs energy emanating...
# 383            air-lock   RAYQUAZA lived for hundreds of millions of yea...
# 643            teravolt   Concealing itself in lightning clouds, it flie...
# 486  pressure telepathy   A Pokémon that is said to live in a world on t...

# %%
plt.figure(figsize=(12,6))
plt.bar(df_top10.name,df_top10['total'], color='black')

plt.title('Top 10 Pokemons overall')
plt.xlabel('Pokemon name')
plt.ylim(640, df_top10.total.max()+10)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1025 non-null   int64
#  1   name          1025 non-null   object
#  2   rank          1025 non-null   object
#  3   generation    1025 non-null   object
#  4   evolves_from  1025 non-null   object
#  5   type1         1025 non-null   object
#  6   type2         526 non-null    object
#  7   hp            1025 non-null   int64
#  8   atk           1025 non-null   int64
#  9   def           1025 non-null   int64
#  10  spatk         1025 non-null   int64
#  11  spdef         1025 non-null   int64
#  12  speed         1025 non-null   int64
#  13  total         1025 non-null   int64
#  14  height        1025 non-null   int64
#  15  weight        1025 non-null   int64
#  16  abilities     1025 non-null   object
#  17  desc          1025 non-null   object
# dtypes: int64(10), object(8)
# memory usage: 144.3+ KB

# %% [markdown]
# ## 3.4 Legendary Pokemon Analysis

# %%
df.rename(columns={'rank': 'pokerank'}, inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'name', 'pokerank', 'generation', 'evolves_from', 'type1',
#        'type2', 'hp', 'atk', 'def', 'spatk', 'spdef', 'speed', 'total',
#        'height', 'weight', 'abilities', 'desc'],
#       dtype='object')

# %%
df.pokerank.unique()
# Out:
# array(['ordinary', 'legendary', 'mythical', 'baby'], dtype=object)

# %%
df.pokerank.value_counts()
# Out:
# pokerank
# ordinary     913
# legendary     70
# mythical      23
# baby          19
# Name: count, dtype: int64

# %% [markdown]
# Grouping by and checking stats for these pokemons

# %%
df_rank=df.groupby(df.pokerank)[columns_to_show].mean()
df_rank
# Out:
#                   atk        def       total
# pokerank
# baby        39.157895  38.421053  274.473684
# legendary  103.214286  97.342857  594.714286
# mythical   103.347826  98.913043  586.086957
# ordinary    75.699890  70.647317  414.078861

# %%
plt.figure(figsize=(12,6))

w=0.3
x=np.arange(len(df_rank.index))
plt.bar(x, df_rank.atk, w, color='red', label='Attack')
plt.bar(x+w, df_rank['def'], w, color='blue', label='Defense')

plt.xticks(x+(w/2), df_rank.index)
plt.ylabel('Pokemon rank')
plt.legend()
plt.show;

# %%
plt.figure(figsize=(4,6))

plt.bar(df_rank.index,df_rank.atk, color='black', label='Total')


plt.ylabel('Pokemon rank')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ratio = df_rank.loc['legendary', 'total'] / df_rank.loc['ordinary', 'total']
ratio
# Out:
# 1.4362343550316694

# %% [markdown]
# #### Analysis Focus: Legendary Pokémon
#
# For the focus of our analysis, we will be analyzing the **Legendary Pokémon**.
#
# - **Legendary Pokémon** are unique, meaning there is only one of each kind.
# - Legendary Pokémon have very high attack and defense stats.
#
# As we see above, legendary Pokémon have **1.4x more total stats on average** compared to ordinary Pokémon.
#
# **Hence, every Pokémon player should own at least one Legendary Pokémon.**

# %% [markdown]
# ### 3.4.1 Top 10 Legendary Pokemon

# %%
df_leg=df[df.pokerank == 'legendary']
df_leg.head()
# Out:
#       id      name   pokerank     generation evolves_from     type1   type2  \
# 143  144  articuno  legendary   generation-i      nothing       ice  flying
# 144  145    zapdos  legendary   generation-i      nothing  electric  flying
# 145  146   moltres  legendary   generation-i      nothing      fire  flying
# 149  150    mewtwo  legendary   generation-i      nothing   psychic     NaN
# 242  243    raikou  legendary  generation-ii      nothing  electric     NaN
#
#       hp  atk  def  spatk  spdef  speed  total  height  weight  \
# 143   90   85  100     95    125     85    580      17     554
# 144   90   90   85    125     90    100    580      16     526
# 145   90  100   90    125     85     90    580      20     600
# 149  106  110   90    154     90    130    680      20    1220
# 242   90   85   75    115    100    115    580      19    1780
#
#                  abilities                                               desc
# 143   pressure snow-cloak   A legendary bird POKéMON that is said to appea...
# 144       pressure static   A legendary bird POKéMON that is said to appea...
# 145   pressure flame-body   Known as the legendary bird of fire. Every fla...
# 149      pressure unnerve   It was created by a scientist after years of h...
# 242  pressure inner-focus   The rain clouds it carries let it fire thunder...

# %%
df_leg10 = df_leg.sort_values('total', ascending=False).head(10)
df_leg10.head()
# Out:
#       id       name   pokerank       generation evolves_from   type1  \
# 889  890  eternatus  legendary  generation-viii      nothing  poison
# 383  384   rayquaza  legendary   generation-iii      nothing  dragon
# 643  644     zekrom  legendary     generation-v      nothing  dragon
# 642  643   reshiram  legendary     generation-v      nothing  dragon
# 716  717    yveltal  legendary    generation-vi      nothing    dark
#
#         type2   hp  atk  def  spatk  spdef  speed  total  height  weight  \
# 889    dragon  140   85   95    145     95    130    690     200    9500
# 383    flying  105  150   90    150     90     95    680      70    2065
# 643  electric  100  150  120    120    100     90    680      29    3450
# 642      fire  100  120  100    150    120     90    680      32    3300
# 716    flying  126  131   95    131     98     99    680      58    2030
#
#        abilities                                               desc
# 889    pressure   The core on its chest absorbs energy emanating...
# 383    air-lock   RAYQUAZA lived for hundreds of millions of yea...
# 643    teravolt   Concealing itself in lightning clouds, it flie...
# 642  turboblaze   This Pokémon appears in legends. It sends flam...
# 716   dark-aura   When this legendary Pokémon’s wings and tail f...

# %%
plt.figure(figsize=(9,4))
plt.bar(df_leg10.name,df_leg10['total'], color='black')

plt.title('Top 10 Legendary Pokemons')
plt.xlabel('Pokemon name')
plt.ylim(640, df_leg10.total.max()+10)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 3.4.2 Legendary Pokemon per type

# %%
df_leg.sort_values(by=['atk','total'], ascending=False).head()
# Out:
#       id       name   pokerank       generation evolves_from   type1  \
# 485  486  regigigas  legendary    generation-iv      nothing  normal
# 383  384   rayquaza  legendary   generation-iii      nothing  dragon
# 643  644     zekrom  legendary     generation-v      nothing  dragon
# 382  383    groudon  legendary   generation-iii      nothing  ground
# 895  896  glastrier  legendary  generation-viii      nothing     ice
#
#         type2   hp  atk  def  spatk  spdef  speed  total  height  weight  \
# 485       NaN  110  160  110     80    110    100    670      37    4200
# 383    flying  105  150   90    150     90     95    680      70    2065
# 643  electric  100  150  120    120    100     90    680      29    3450
# 382       NaN  100  150  140    100     90     90    670      35    9500
# 895       NaN  100  145  130     65    110     30    580      22    8000
#
#            abilities                                               desc
# 485      slow-start   There is an enduring legend that states this P...
# 383        air-lock   RAYQUAZA lived for hundreds of millions of yea...
# 643        teravolt   Concealing itself in lightning clouds, it flie...
# 382         drought   GROUDON has long been described in mythology a...
# 895  chilling-neigh   Glastrier emits intense cold from its hooves. ...

# %%
legen=df_leg.type1.value_counts()
legen
# Out:
# type1
# psychic     13
# dragon       8
# electric     6
# dark         5
# poison       4
# fire         4
# water        4
# fighting     4
# grass        3
# fairy        3
# ice          3
# normal       3
# steel        3
# ghost        2
# rock         2
# ground       2
# flying       1
# Name: count, dtype: int64

# %%
df_leg_type=pd.DataFrame(legen)

# %%
df_leg_type
# Out:
#           count
# type1
# psychic      13
# dragon        8
# electric      6
# dark          5
# poison        4
# fire          4
# water         4
# fighting      4
# grass         3
# fairy         3
# ice           3
# normal        3
# steel         3
# ghost         2
# rock          2
# ground        2
# flying        1

# %%
df_leg_type.reset_index(inplace=True)

# %%
df_leg_type.columns
# Out:
# Index(['type1', 'count'], dtype='object')

# %%
plt.figure(figsize=(10,6))
plt.bar(df_leg_type.type1,df_leg_type['count'])

plt.xlabel('Type 1')
plt.ylabel('Count')
plt.title('Count of Legendary Pokemon per type')
plt.xticks(rotation=45);

# %%
#Legendary pokemon types by stats
df_leg.groupby(df_leg.type1)[columns_to_show].mean().sort_values(by=['total','atk','def'],ascending=False).head()
# Out:
#           atk         def  total
# type1
# fairy   122.0   93.333333  640.0
# ground  137.5  115.000000  635.0
# dragon  115.0   92.625000  635.0
# ghost    82.5   90.000000  630.0
# water    92.5  105.000000  625.0
